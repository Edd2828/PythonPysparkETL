# %%
# %run '01 bronze.ipynb'
# Out:
# --------------------------------------------------
# Reading from raw from: green_tripdata_2021-01.csv
# Writing into bronze: Green
# Successfully saved data in location:
# ./PipelineData/Bronze/Green
# Row count (Green): 76539
# Column count (Green): 20
# ['VendorID', 'lpep_pickup_datetime', 'lpep_dropoff_datetime', 'store_and_fwd_flag', 'RatecodeID', 'PULocationID', 'DOLocationID', 'passenger_count', 'trip_distance', 'fare_amount', 'extra', 'mta_tax', 'tip_amount', 'tolls_amount', 'ehail_fee', 'improvement_surcharge', 'total_amount', 'payment_type', 'trip_type', 'congestion_surcharge']
# --------------------------------------------------
# Reading from raw from: yellow_tripdata_2021-01.csv
# Writing into bronze: Yellow
# Successfully saved data in location:
# ./PipelineData/Bronze/Yellow
# Row count (Yellow): 1369819
# Column count (Yellow): 18
# ...

# %%
# %run '02 silver.ipynb'
# Out:
# --------------------------------------------------
# Writing into silver: GY_PRE_VALIDATION
# Successfully saved data in location:
# ./PipelineData/Silver/GY_PRE_VALIDATION
# --------------------------------------------------
# Writing into silver: GY_VALID
# Successfully saved data in location:
# ./PipelineData/Silver/GY_VALID
# --------------------------------------------------
# Writing into silver: GY_INVALID
# Successfully saved data in location:
# ./PipelineData/Silver/GY_INVALID
# --------------------------------------------------
# Running test to check if counts match...
# Counts match: 1446358
# GY_PRE_VALIDATION: 1446358
# Union of GY_VALID and GY_INVALID: 1446358

# %%
# %run '03 gold.ipynb'
# Out:
# --------------------------------------------------
# Writing into gold: Locations
# Successfully saved data in location:
# ./PipelineData/Gold/Locations
# --------------------------------------------------
# Writing into gold: Vendors
# Successfully saved data in location:
# ./PipelineData/Gold/Vendors

# %%
# %run '04 gold test.ipynb'
# Out:
# --------------------------------------------------
# Validating the 'Locations' table and filtering the column 'PickUpLocationId' = '53'
# The gold 'Locations' filtering the column 'LocationId' = '53'
# Validating the gold column value 'Total Fares by pickup location'
# Silver: 745.3 (sum)
# Gold  : 745.3000020980835 (sum)
# --------------------------------------------------
# Validating the 'Locations' table and filtering the column 'PickUpLocationId' = '53'
# The gold 'Locations' filtering the column 'LocationId' = '53'
# Validating the gold column value 'Total Tip Amount by pickup location'
# Silver: 15.82 (sum)
# Gold  : 15.82 (sum)
# --------------------------------------------------
# Validating the 'Locations' table and filtering the column 'PickUpLocationId' = '53'
# The gold 'Locations' filtering the column 'LocationId' = '53'
# Validating the gold column value 'The average distance by pickup location'
# Silver: 3.32 (avg)
# Gold  : 3.32 (avg)
# ...
